# %% [markdown]
# ## «Модель прогнозирования стоимости жилья для агентства недвижимости»

# %% [markdown]
# #### Этап создания модели

# %%
import random
import numpy as np 
import pandas as pd 
import sys
import optuna

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate
from sklearn.compose import TransformedTargetRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import SGDRegressor
from catboost import CatBoostRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import KFold
from sklearn import metrics
from tqdm.notebook import tqdm
from category_encoders import TargetEncoder, CatBoostEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures


# plt
import matplotlib.pyplot as plt
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg' 
# %matplotlib inline
#отключим оповещения
import warnings
warnings.filterwarnings("ignore")

# %%
# зафиксируем RANDOM_SEED, чтобы эксперименты были воспроизводимы
RANDOM_SEED = 42
TEST_SIZE = 0.2

# %%
df = pd.read_csv('data/data_model.csv')
display(df.head())
df.info()
# Out:
#      status  baths            city  sqft  zipcode state  target  pool_encoded  \
# 0    Active    4.0  Southern Pines  2900    28387    NC  418000         False
# 1  For Sale    3.0  Spokane Valley  1947    99216    WA  310000         False
# 2    Active    2.0           Mason  3588    50401    IA  244900         False
# 3     Other    3.0         Houston  1930    77080    TX  311995         False
# 4  For Sale    2.0        Flushing  1300    11354    NY  669000         False
#
#                  Type Year built  Heating_encoded  Cooling_encoded  \
# 0  single_family_home       2019             True            False
# 1  single_family_home       2019            False            False
# 2  single_family_home       1970             True             True
# 3  single_family_home       2019             True             True
# 4               condo       1965            False            False
#
#    Parking_encoded  fireplace_encoded  school_rating _mean  school_dist_min
# 0            False               True                  5.2             2.70
# 1            False              False                  4.0             1.01
# 2            False              False                  3.8             5.60
# 3             True              False                  3.0             0.60
# 4             True              False                  2.8             0.30
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210669 entries, 0 to 210668
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   status               210669 non-null  object
#  1   baths                210669 non-null  float64
#  2   city                 210669 non-null  object
#  3   sqft                 210669 non-null  int64
#  4   zipcode              210669 non-null  int64
#  5   state                210669 non-null  object
#  6   target               210669 non-null  int64
#  7   pool_encoded         210669 non-null  bool
#  8   Type                 210669 non-null  object
#  9   Year built           210669 non-null  object
#  10  Heating_encoded      210669 non-null  bool
#  11  Cooling_encoded      210669 non-null  bool
#  12  Parking_encoded      210669 non-null  bool
#  13  fireplace_encoded    210669 non-null  bool
#  14  school_rating _mean  210669 non-null  float64
#  15  school_dist_min      210669 non-null  float64
# dtypes: bool(5), float64(3), int64(3), object(5)
# memory usage: 18.7+ MB

# %%
# Составим список булевых признаков:
bin_features = ['pool_encoded','Heating_encoded','Cooling_encoded','Parking_encoded','fireplace_encoded']

# Составим список категориальных признаков:
cat_features = ['status','city','zipcode','state','Type','Year built']
 
# Составим список числовых признаков:
num_features = ['baths', 'sqft', 'target', 'school_rating _mean', 'school_dist_min']

# %%
# подсчет количества уникальных значений в каждой категориальной колонке
for col in cat_features:
   unique_values = df[col].nunique()
   print(f"Количество уникальных значений в категориальной колонке {col}: {unique_values}")
# Out:
# Количество уникальных значений в категориальной колонке status: 12
# Количество уникальных значений в категориальной колонке city: 1522
# Количество уникальных значений в категориальной колонке zipcode: 3962
# Количество уникальных значений в категориальной колонке state: 34
# Количество уникальных значений в категориальной колонке Type: 12
# Количество уникальных значений в категориальной колонке Year built: 205

# %%
def preproc_data(df_input):
    '''includes several functions to pre-process the predictor data.'''
    
    df_output = df_input.copy()
    # переведем признак зип кода в категориальный
    df_output['zipcode'] = df_output['zipcode'].astype(str)
    # переведем признак год в категориальный
    df_output['Year built'] = df_output['Year built'].astype(str)
    # Нормализация и логорифмирование данных
    #scaler = MinMaxScaler()
    for column in ['baths', 'sqft', 'target', 'school_rating _mean', 'school_dist_min']:
        #df_output[column] = scaler.fit_transform(df_output[[column]])[:,0]
        # Логорифмирование
        df_output[column] = df_output[column].apply(lambda x: abs(x))
        constant = 1e-6
        df_output[column] = np.log(df_output[column] + constant)
        
    # ################### Categorical Features ############################################################## 
 
    ohe_status = OneHotEncoder(sparse=False)
    ohe_state = OneHotEncoder(sparse=False)
    ohe_Type = OneHotEncoder(sparse=False)

    status_ohe = ohe_status.fit_transform(df_output['status'].values.reshape(-1,1))
    state_ohe = ohe_state.fit_transform(df_output['state'].values.reshape(-1,1))
    Type_ohe = ohe_Type.fit_transform(df_output['Type'].values.reshape(-1,1))

    le = LabelEncoder()
    state_label = le.fit_transform(df_output['state'])

    year_le = LabelEncoder()
    year_ord = year_le.fit_transform(df_output['Year built'])

    city_le = LabelEncoder()
    city_label = city_le.fit_transform(df_output['city'])

    zip_le = LabelEncoder()
    zip_label = zip_le.fit_transform(df_output['zipcode'])

    # Adding encoded categorical features to the output dataframe
    df_output = df_output.join(pd.DataFrame(status_ohe, columns=['status_' + str(cat) for cat in ohe_status.categories_[0]]))
    df_output = df_output.join(pd.DataFrame(state_ohe, columns=['state_' + str(cat) for cat in ohe_state.categories_[0]]))
    df_output = df_output.join(pd.DataFrame(Type_ohe, columns=['Type_' + str(cat) for cat in ohe_Type.categories_[0]]))
    df_output['state_label'] = state_label
    df_output['year_ord'] = year_ord
    df_output['city_label'] = city_label
    df_output['zip_label'] = zip_label

    # Dropping original categorical columns
    df_output.drop(['status', 'state', 'Type', 'city', 'zipcode','Year built'], axis=1, inplace=True)
    
    return df_output

# %%
# Запускаем и проверяем, что получилось
df_encoded = preproc_data(df)
df_encoded.sample(10)
# Out:
#            baths      sqft     target  pool_encoded  Heating_encoded  \
# 1455    0.693148  7.151485  12.834415         False             True
# 5566    0.693148  7.570959  12.506140         False             True
# 22949   0.693148  6.946976  11.694413         False             True
# 177191  1.386295  8.169053  12.959609         False             True
# 173471  0.693148  7.103322  11.849398         False             True
# 141116  1.386295  8.114325  12.896717         False             True
# 30939   1.386295  8.241703  12.793581          True             True
# 77862   0.693148  7.267525  12.100712         False             True
# 27792   0.693148  7.327123  12.072541         False             True
# 3968    0.693148  7.494430  12.608165         False            False
#
#         Cooling_encoded  Parking_encoded  fireplace_encoded  \
# 1455               True             True              False
# 5566               True             True              False
# 22949              True            False              False
# 177191             True             True              False
# 173471            False             True               True
# 141116             True            False               True
# 30939              True             True              False
# 77862              True            False              False
# 27792              True             True               True
# 3968              False            False              False
#
#         school_rating _mean  school_dist_min  ...  Type_modern  \
# 1455               0.788458        -1.966106  ...          0.0
# 5566               2.079442        -0.105359  ...          0.0
# 22949              1.386295         1.163151  ...          0.0
# 177191             1.667707         0.587787  ...          0.0
# 173471             1.163151        -0.798505  ...          0.0
# 141116             2.079442        -0.105359  ...          0.0
# 30939              1.840550         0.182322  ...          0.0
# 77862              1.308333        -0.916288  ...          0.0
# 27792              1.547563        -0.776527  ...          0.0
# 3968               2.197225         1.147403  ...          0.0
#
#         Type_multi_family_home  Type_other  Type_ranch  \
# 1455                       1.0         0.0         0.0
# 5566                       0.0         0.0         0.0
# 22949                      0.0         0.0         0.0
# 177191                     0.0         0.0         0.0
# 173471                     0.0         0.0         0.0
# 141116                     0.0         0.0         0.0
# 30939                      0.0         0.0         0.0
# 77862                      0.0         0.0         0.0
# 27792                      0.0         0.0         0.0
# 3968                       0.0         0.0         0.0
#
#         Type_single_family_home  Type_townhouse  state_label  year_ord  \
# 1455                        0.0             0.0            5       117
# 5566                        1.0             0.0           28       201
# 22949                       0.0             0.0            5       187
# 177191                      1.0             0.0            5       175
# 173471                      1.0             0.0            8       109
# 141116                      1.0             0.0           22       139
# 30939                       1.0             0.0           28       173
# 77862                       0.0             0.0            5       188
# 27792                       1.0             0.0           28       165
# 3968                        1.0             0.0            5       204
#
#         city_label  zip_label
# 1455           833       1065
# 5566          1182       2666
# 22949         1081       1236
# 177191         644        928
# 173471         242       2072
# 141116        1025       1598
# 30939          608       2503
# 77862          692       1299
# 27792         1182       2635
# 3968          1169        931
#
# [10 rows x 72 columns]

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210669 entries, 0 to 210668
# Data columns (total 72 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   baths                    210669 non-null  float64
#  1   sqft                     210669 non-null  float64
#  2   target                   210669 non-null  float64
#  3   pool_encoded             210669 non-null  bool
#  4   Heating_encoded          210669 non-null  bool
#  5   Cooling_encoded          210669 non-null  bool
#  6   Parking_encoded          210669 non-null  bool
#  7   fireplace_encoded        210669 non-null  bool
#  8   school_rating _mean      210669 non-null  float64
#  9   school_dist_min          210669 non-null  float64
#  10  status_Active            210669 non-null  float64
#  11  status_Auction           210669 non-null  float64
#  12  status_Back on Market    210669 non-null  float64
#  13  status_Coming Soon       210669 non-null  float64
#  14  status_Contingent        210669 non-null  float64
#  15  status_For Rent          210669 non-null  float64
#  16  status_For Sale          210669 non-null  float64
#  17  status_Foreclosure       210669 non-null  float64
#  18  status_Other             210669 non-null  float64
#  19  status_Pending           210669 non-null  float64
#  20  status_Price Change      210669 non-null  float64
#  21  status_Under Contract    210669 non-null  float64
#  22  state_AZ                 210669 non-null  float64
#  23  state_CA                 210669 non-null  float64
#  24  state_CO                 210669 non-null  float64
#  25  state_DC                 210669 non-null  float64
#  26  state_DE                 210669 non-null  float64
#  27  state_FL                 210669 non-null  float64
#  28  state_GA                 210669 non-null  float64
#  29  state_IA                 210669 non-null  float64
#  30  state_IL                 210669 non-null  float64
#  31  state_IN                 210669 non-null  float64
#  32  state_KY                 210669 non-null  float64
#  33  state_MA                 210669 non-null  float64
#  34  state_MD                 210669 non-null  float64
#  35  state_ME                 210669 non-null  float64
#  36  state_MI                 210669 non-null  float64
#  37  state_MO                 210669 non-null  float64
#  38  state_MS                 210669 non-null  float64
#  39  state_MT                 210669 non-null  float64
#  40  state_NC                 210669 non-null  float64
#  41  state_NJ                 210669 non-null  float64
#  42  state_NV                 210669 non-null  float64
#  43  state_NY                 210669 non-null  float64
#  44  state_OH                 210669 non-null  float64
#  45  state_OK                 210669 non-null  float64
#  46  state_OR                 210669 non-null  float64
#  47  state_PA                 210669 non-null  float64
#  48  state_SC                 210669 non-null  float64
#  49  state_TN                 210669 non-null  float64
#  50  state_TX                 210669 non-null  float64
#  51  state_UT                 210669 non-null  float64
#  52  state_VA                 210669 non-null  float64
#  53  state_VT                 210669 non-null  float64
#  54  state_WA                 210669 non-null  float64
#  55  state_WI                 210669 non-null  float64
#  56  Type_apartment           210669 non-null  float64
#  57  Type_condo               210669 non-null  float64
#  58  Type_historical          210669 non-null  float64
#  59  Type_land                210669 non-null  float64
#  60  Type_miscellaneous       210669 non-null  float64
#  61  Type_mobile_home         210669 non-null  float64
#  62  Type_modern              210669 non-null  float64
#  63  Type_multi_family_home   210669 non-null  float64
#  64  Type_other               210669 non-null  float64
#  65  Type_ranch               210669 non-null  float64
#  66  Type_single_family_home  210669 non-null  float64
#  67  Type_townhouse           210669 non-null  float64
#  68  state_label              210669 non-null  int64
#  69  year_ord                 210669 non-null  int64
#  70  city_label               210669 non-null  int64
#  71  zip_label                210669 non-null  int64
# dtypes: bool(5), float64(63), int64(4)
# memory usage: 108.7 MB

# %% [markdown]
# Разделим датасет

# %%
y = df_encoded.target.values
X = df_encoded.drop(['target'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True, random_state=RANDOM_SEED)

# %% [markdown]
# # Обучение модели

# %% [markdown]
# ## Model 1: Создадим "наивную" модель
# Эта модель будет предсказывать среднюю стоимость по общей площади и городу.
# C ней будем сравнивать другие модели.

# %%
# Наивная модель
class NaiveModel:
    def __init__(self):
        self.means = None

    def fit(self, X, y):
        X_df = pd.DataFrame(X, columns=['city_label'])
        y_df = pd.DataFrame(y, columns=['target'])
        df = pd.concat([X_df, y_df], axis=1)
        self.means = df.groupby(['city_label'])['target'].mean().reset_index()

    def predict(self, X):
        X = pd.DataFrame(X, columns=['city_label']).copy()
        X['mean'] = np.nan
        for idx, row in self.means.iterrows():
            X.loc[(X['city_label'] == row['city_label']), 'mean'] = row['target']
        
        X['mean'].fillna(X['mean'].mean(), inplace=True)
        return X['mean'].to_numpy()

naive_model = NaiveModel()
naive_model.fit(X_train, y_train)
y_pred_train = naive_model.predict(X_train)
y_pred_test = naive_model.predict(X_test)

mse_train = mean_squared_error(y_train, y_pred_train)
mse_test = mean_squared_error(y_test, y_pred_test)
mae_train = mean_absolute_error(y_train, y_pred_train)
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)

print(f"Train MSE: {mse_train:.2f}")
print(f"Test MSE: {mse_test:.2f}")
print(f"Train MAE: {mae_train:.2f}")
print(f"Test MAE: {mae_test:.2f}")
print(f"Train R2: {r2_train:.2f}")
print(f"Test R2: {r2_test:.2f}")
# Out:
# Train MSE: 0.43
# Test MSE: 0.43
# Train MAE: 0.48
# Test MAE: 0.48
# Train R2: -0.00
# Test R2: -0.00

# %% [markdown]
# По полученным метрикам качества модели можно сделать следующий вывод:
#
# MSE (Mean Squared Error) и MAE (Mean Absolute Error) практически одинаковы на тренировочном и тестовом наборах данных, что свидетельствует о хорошем обобщении модели и отсутствии значительного переобучения или недообучения.
# Однако обе метрики показывают относительно высокие значения (около 0.43 для MSE и около 0.48 для MAE), что означает, что средняя ошибка предсказания достаточно велика.
# Значение коэффициента детерминации равно 0.00, как на тренировочной выборке, так и на тестовой. Это говорит о том, что построенная модель объясняет лишь незначительную долю дисперсии целевой переменной, либо вообще её не объясняет, а качество модели сопоставимо с константным предсказанием среднего значения.
# Таким образом, выводы:
# Модель хорошо обобщается на новые данные, поскольку показатели качества совпадают на обучении и тестировании.
# Тем не менее, сама модель недостаточно хороша, так как точность низкая, а коэффициент детерминации близок к 0.

# %% [markdown]
# ## Model 2: LinearRegression

# %%
# создаём модель линейной регрессии
model = LinearRegression(fit_intercept=False)

# вычисляем коэффициенты регрессии
model.fit(X_train, y_train)

# делаем предсказания с помощью модели
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# вычисляем требуемые метрики
mse_train = metrics.mean_squared_error(y_train, y_train_pred)
mse_test = metrics.mean_squared_error(y_test, y_test_pred)
mae_train = metrics.mean_absolute_error(y_train, y_train_pred)
mae_test = metrics.mean_absolute_error(y_test, y_test_pred)
r2_train = metrics.r2_score(y_train, y_train_pred)
r2_test = metrics.r2_score(y_test, y_test_pred)

# выводим метрики
print(f"Train MSE: {mse_train:.2f}")
print(f"Test MSE: {mse_test:.2f}")
print(f"Train MAE: {mae_train:.2f}")
print(f"Test MAE: {mae_test:.2f}")
print(f"Train R2: {r2_train:.2f}")
print(f"Test R2: {r2_test:.2f}")
# Out:
# Train MSE: 0.23
# Test MSE: 0.23
# Train MAE: 0.35
# Test MAE: 0.34
# Train R2: 0.45
# Test R2: 0.45

# %% [markdown]
# По полученным метрическим показателям можно сделать следующий вывод:
#
# MSE (Mean Squared Error) и MAE (Mean Absolute Error) примерно равны на обоих наборах данных (тренировочном и тестовом), что является хорошим признаком отсутствия переобучения или сильного недообучения модели.
# Среднее квадратичное отклонение (MSE) составляет всего 0.23, а среднее абсолютное отклонение (MAE) чуть больше — около 0.35, что показывает приемлемый уровень точности моделей.
# Коэффициент детерминации, равный приблизительно 0.45, говорит о том, что построенная модель способна объяснить примерно 45% вариации целевого признака. Хотя это не идеальное значение, оно всё-таки положительно и значит, что модель лучше случайного выбора средней величины зависимой переменной.
# Однако коэффициент, близкий к половине, сигнализирует о наличии пространства для улучшений:
#
# Возможно стоит рассмотреть дополнительные признаки или попробовать другую спецификацию модели.
# Важно убедиться, что проверка производится на репрезентативной выборке данных.
# Резюме:Модель имеет хорошее обобщающее свойство и демонстрирует умеренную точность. Для дальнейшего повышения эффективности рекомендуется провести дополнительную работу над подбором характеристик и моделью.

# %% [markdown]
# ## Model 3: RandomForestRegressor

# %%
# Создаем экземпляр модели RandomForestRegressor
rf_regressor = RandomForestRegressor(random_state=RANDOM_SEED)

# Обучаем модель на обучающих данных
rf_regressor.fit(X_train, y_train)

# Предсказания на обучающих и тестовых данных
y_train_pred = rf_regressor.predict(X_train)
y_test_pred = rf_regressor.predict(X_test)

# Вычисляем метрики
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
mae_train = mean_absolute_error(y_train, y_train_pred)
mae_test = mean_absolute_error(y_test, y_test_pred)
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

# Выводим метрики
print(f"Train MSE: {mse_train:.2f}")
print(f"Test MSE: {mse_test:.2f}")
print(f"Train MAE: {mae_train:.2f}")
print(f"Test MAE: {mae_test:.2f}")
print(f"Train R2: {r2_train:.2f}")
print(f"Test R2: {r2_test:.2f}")
# Out:
# Train MSE: 0.01
# Test MSE: 0.07
# Train MAE: 0.06
# Test MAE: 0.16
# Train R2: 0.98
# Test R2: 0.84

# %% [markdown]
# Анализ представленных метрик позволяет сделать следующие выводы:
#
# Оценка результатов на тренировочных данных:
# MSE (средняя квадратичная ошибка) равна 0.01, что свидетельствует о крайне низкой ошибке на тренировочном наборе.
# MAE (средняя абсолютная ошибка) также минимальна и равна 0.06.
# Высокое значение коэффициента детерминации равное 0.98 подтверждает, что модель отлично описывает тренировочные данные.
# Эти показатели указывают на высокую эффективность модели на тренировочной выборке.
#
# Оценка результатов на тестовых данных:
# MSE значительно возрастает до 0.07, а MAE увеличивается до 0.16. Эти изменения демонстрируют ухудшение качества модели на новых, ранее невиданных данных.
# Значение коефициента детерминацц снижается до 0.84, что остается высоким показателем, но заметно ниже, чем на тренировочных данных.
# Несмотря на значительное повышение ошибок на тестовом наборе, общие показатели остаются хорошими, свидетельствуя о разумном уровне обобщающей способности модели.
#
# Итоговые рекомендации:
# Хотя наблюдаются некоторые признаки небольшого переобучения (разрыв между показателями на train/test), модель остаётся эффективной. Можно предпринять следующие меры для оптимизации:
#
# Регуляризация (L1/L2), уменьшение сложности модели, кросс-валидация.
# Анализ особенностей распределения тестового набора данных, возможно различие состава или структуры данных.
# Добавление новых признаков или улучшение существующих признаков.
# Общий итог: модель работает эффективно, но имеет потенциал для небольшой доработки.

# %% [markdown]
# ## Model 4: ElasticNetCV

# %%
# Создаем и тренируем модель ElasticNetCV с кросс-валидацией по 5 фолдам
model_el = ElasticNetCV(cv=5, random_state=RANDOM_SEED)
model_el.fit(X_train, y_train)

# Предсказания для обучающей и тестовой выборок
y_train_pred = model_el.predict(X_train)
y_test_pred = model_el.predict(X_test)

# MSE
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)

# MAE
mae_train = mean_absolute_error(y_train, y_train_pred)
mae_test = mean_absolute_error(y_test, y_test_pred)

# R2
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

# Выводим метрики
print(f"Train MSE: {mse_train:.2f}")
print(f"Test MSE: {mse_test:.2f}")
print(f"Train MAE: {mae_train:.2f}")
print(f"Test MAE: {mae_test:.2f}")
print(f"Train R2: {r2_train:.2f}")
print(f"Test R2: {r2_test:.2f}")
# Out:
# Train MSE: 0.37
# Test MSE: 0.38
# Train MAE: 0.45
# Test MAE: 0.45
# Train R2: 0.12
# Test R2: 0.11

# %% [markdown]
# Полученные метрики позволяют сделать следующие выводы:
#
# Среднеквадратичная ошибка (MSE) и средняя абсолютная ошибка (MAE) почти одинаковы на тренировочной и тестовой выборках, что говорит о хорошей способности модели переносить знания на новую выборку. Разница между этими двумя наборами невелика, что снижает вероятность проблемы переобучения или недообучения.
# Величина ошибок MSE (0.37–0.38) и MAE (0.45) указывает на средний уровень точности. Ошибки не маленькие, но и не критически большие. Следовательно, качество предсказаний находится на среднем уровне.
# Коэффициент детерминации довольно низок как на тренировочной выборке (0.12), так и на тестовой (0.11). Низкое значение говорит о слабой объясняющей способности модели. Она едва справляется с объяснением зависимости в данных и большая доля изменений в целевой переменной остаётся необъяснённой.
# Общие выводы:
# Модель стабильна, хорошая способность к обобщению, так как разницы в результатах тренировки и тестирования почти нет.
# Точность модели оставляет желать лучшего, особенно учитывая низкий показатель коэффициента детерминации.
# Итог: модель пригодна для базового анализа, но требует значительных улучшений для достижения высоких показателей точности.

# %% [markdown]
# ## Model 5: CatBoostRegressor

# %% [markdown]
# CatBoostRegressor позволяет работать с необработанными категориальными данными, в отличие от некоторых других алгоритмов машинного обучения, которые требуют предварительной обработки данных, такой как кодирование категориальных переменных в числовые значения.

# %%
def log_data(df_input):
    '''includes several functions to pre-process the predictor data.'''
    
    df_output = df_input.copy()
    # переведем признак зип кода в категориальный
    df_output['zipcode'] = df_output['zipcode'].astype(str)
    # переведем признак год в категориальный
    df_output['Year built'] = df_output['Year built'].astype(str)
    # Нормализация данных и логорифмирование
    #scaler = MinMaxScaler()
    for column in num_features:
        #df_output[column] = scaler.fit_transform(df_output[[column]])[:,0]
        # Логорифмирование
        df_output[column] = df_output[column].apply(lambda x: abs(x))
        constant = 1e-6
        df_output[column] = np.log(df_output[column] + constant)
    return df_output

# %%
# Запускаем и проверяем, что получилось
df_log = log_data(df)
df_log.sample(5)
# Out:
#              status     baths            city      sqft  zipcode state  \
# 204768        Other  0.693148        Live Oak  7.304516    78233    TX
# 2844          Other  1.098613     San Antonio  7.643962    78221    TX
# 3805    Foreclosure  1.098613         Seattle  7.056175    98198    WA
# 27911        Active  0.693148        Suitland  7.166266    20746    MD
# 160775     For Sale  0.693148  Pt Saint Lucie  7.412160    34984    FL
#
#            target  pool_encoded                Type Year built  \
# 204768  12.031719         False  single_family_home       1970
# 2844    12.303789         False  single_family_home       2019
# 3805    12.808748         False  single_family_home       1942
# 27911   12.611538         False  single_family_home       1935
# 160775  12.205573         False  single_family_home       1998
#
#         Heating_encoded  Cooling_encoded  Parking_encoded  fireplace_encoded  \
# 204768             True             True             True               True
# 2844               True             True             True               True
# 3805               True             True             True               True
# 27911              True             True             True              False
# 160775             True             True             True              False
#
#         school_rating _mean  school_dist_min
# 204768             0.916291        -1.203969
# 2844               1.193923        -0.356674
# 3805               1.458615        -0.223142
# 27911              0.788458        -1.203969
# 160775             1.667707         0.943906

# %%
y = df_log.target.values
X = df_log.drop(['target'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle=True, random_state=RANDOM_SEED)

# %%
param_grid = {
    'iterations': [100, 300, 500],
    'learning_rate': [0.01, 0.03, 0.1],
    'depth': [4, 6, 8],
    'l2_leaf_reg': [1, 3, 5],
}
cb_model = CatBoostRegressor(random_seed=RANDOM_SEED, silent=True)
grid_search = GridSearchCV(estimator=cb_model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', verbose=2, n_jobs=-1)
grid_search.fit(X_train, y_train, cat_features=cat_features)
best_params = grid_search.best_params_
best_cb_model = CatBoostRegressor(iterations=best_params['iterations'], learning_rate=best_params['learning_rate'], depth=best_params['depth'], l2_leaf_reg=best_params['l2_leaf_reg'], random_seed=RANDOM_SEED, silent=True)
best_cb_model.fit(X_train, y_train, cat_features=cat_features)

y_train_pred = best_cb_model.predict(X_train)
y_test_pred = best_cb_model.predict(X_test)

mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
mae_train = mean_absolute_error(y_train, y_train_pred)
mae_test = mean_absolute_error(y_test, y_test_pred)
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

print(f"Train MSE: {mse_train:.2f}")
print(f"Test MSE: {mse_test:.2f}")
print(f"Train MAE: {mae_train:.2f}")
print(f"Test MAE: {mae_test:.2f}")
print(f"Train R2: {r2_train:.2f}")
print(f"Test R2: {r2_test:.2f}")
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  18.2s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  18.2s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  18.2s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  18.6s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  16.3s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  16.6s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  16.3s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  16.4s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  17.0s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  16.9s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  16.6s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  16.6s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  15.3s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  15.4s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  15.1s
# [CV] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  15.2s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  15.2s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  15.4s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  15.3s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  15.2s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  15.3s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  15.4s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  15.5s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  15.4s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  15.6s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  15.8s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  15.6s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  15.8s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  19.2s
# [CV] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  19.4s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  19.1s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  19.2s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  20.1s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  20.5s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  20.4s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  20.6s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  18.0s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  18.0s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  18.5s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  18.5s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  18.8s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  18.7s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  18.6s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  18.4s
# [CV] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  20.4s
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 1.6min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 1.6min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 1.7min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 1.7min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 1.4min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 1.4min
# [CV] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 1.4min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 1.3min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 1.4min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 1.4min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 1.4min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 1.3min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 1.8min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 1.8min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 1.8min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 1.9min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 1.8min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 1.7min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 1.7min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 1.7min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 1.4min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 1.4min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 1.7min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 1.6min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 1.5min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 1.2min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 1.3min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 1.3min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 1.3min
# [CV] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 1.3min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 2.3min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 2.4min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 2.4min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 2.8min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 2.6min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 2.4min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 2.4min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 2.4min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 2.5min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 2.6min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 2.6min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 2.6min
# [CV] END depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 2.5min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 2.2min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 2.2min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 2.1min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 2.3min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 2.5min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 3.0min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 3.0min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 3.0min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 2.8min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 2.6min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 2.8min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 2.8min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 2.8min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 2.7min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 2.6min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 2.8min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 2.8min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 2.8min
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 2.8min
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  26.6s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  24.4s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  26.2s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  25.1s
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 2.5min
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  22.8s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  23.7s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  23.9s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  24.5s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  25.0s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  24.5s
# [CV] END depth=4, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 2.1min
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  23.0s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  22.2s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  22.4s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  22.6s
# [CV] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  23.0s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  21.2s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  21.3s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  21.6s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  21.4s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  21.5s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  22.0s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  21.1s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  21.3s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  22.2s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  22.0s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  21.8s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  21.3s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  19.5s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  19.4s
# [CV] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  19.7s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  19.5s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  19.4s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  19.8s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  19.2s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  19.2s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  19.4s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  19.4s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  19.5s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  19.5s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  19.4s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  19.9s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  19.7s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  20.0s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  23.8s
# [CV] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  24.2s
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 2.2min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 2.3min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 2.3min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 2.5min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 2.5min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 2.3min
# [CV] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 2.3min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 2.4min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 2.7min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 2.8min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 2.9min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 3.0min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 3.1min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 3.0min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 2.9min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 2.9min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 2.7min
# [CV] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 2.6min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 2.5min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 2.5min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 2.5min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 2.5min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 2.5min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 2.6min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 2.7min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 2.6min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 2.6min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 2.7min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 2.6min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 2.6min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 2.6min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 2.5min
# [CV] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 2.2min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 4.0min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 4.0min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 4.0min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 4.2min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 3.8min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 3.8min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 3.8min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 4.0min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 4.1min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 4.1min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 4.1min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 3.7min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 4.3min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 4.3min
# [CV] END depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 4.4min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 4.3min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 3.6min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 3.6min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 3.6min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 4.3min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 4.8min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 4.8min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 4.7min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 4.4min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 3.9min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 3.8min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 3.7min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 3.5min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 3.8min
# [CV] END depth=6, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 3.9min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 4.0min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 4.7min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 4.6min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 4.4min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 4.4min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 3.9min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 3.8min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 3.8min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 3.8min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 3.6min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 3.7min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 3.8min
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 3.9min
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  38.5s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  39.0s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  39.7s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  38.8s
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 3.9min
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.01; total time=  35.4s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  35.8s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  39.5s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  37.1s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  34.4s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.03; total time=  32.6s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  32.2s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  37.6s
# [CV] END depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 3.7min
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  32.1s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  31.7s
# [CV] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.1; total time=  27.5s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  27.1s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  28.3s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  30.2s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  28.8s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.01; total time=  30.5s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  33.0s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  32.4s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  31.2s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  29.8s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.03; total time=  25.0s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  23.4s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  21.5s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  21.9s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  21.7s
# [CV] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.1; total time=  21.8s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  21.7s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  21.1s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  21.1s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  21.5s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.01; total time=  25.0s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  27.2s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  28.0s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  28.5s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  30.5s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.03; total time=  32.2s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  30.7s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  29.5s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  30.3s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  31.9s
# [CV] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.1; total time=  34.3s
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 3.6min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 3.7min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 3.6min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 3.6min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.01; total time= 3.7min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 3.9min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 3.9min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 3.9min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 4.0min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.03; total time= 3.9min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 3.8min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 3.8min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 3.7min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 3.7min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 3.6min
# [CV] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.1; total time= 3.8min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 3.4min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 3.2min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 3.3min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.01; total time= 3.3min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 3.6min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 3.5min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 3.5min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 3.5min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.03; total time= 3.2min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 3.2min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 3.2min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 3.4min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 3.3min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 3.1min
# [CV] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.1; total time= 3.2min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 3.0min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 2.9min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 2.9min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.01; total time= 2.9min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 3.1min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 3.8min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 3.8min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 3.8min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.03; total time= 4.0min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 3.8min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 3.8min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 3.8min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 3.8min
# [CV] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.1; total time= 3.5min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 5.9min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 5.9min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 6.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 5.9min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.01; total time= 5.6min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 5.6min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 5.8min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 5.7min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 5.6min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.03; total time= 5.6min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 5.4min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 5.7min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 6.1min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 6.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.1; total time= 6.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 6.1min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 5.9min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 5.9min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 5.9min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.01; total time= 5.4min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 5.3min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 5.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 5.3min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 5.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 5.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 5.3min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 5.4min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 5.5min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 5.3min
# [CV] END depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.1; total time= 5.3min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 5.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 4.9min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 5.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 5.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.01; total time= 5.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 5.7min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 5.8min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 5.8min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 6.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.03; total time= 6.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 5.9min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 5.8min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 5.2min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 3.7min
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time= 2.2min
# Train MSE: 0.06
# Test MSE: 0.07
# Train MAE: 0.17
# Test MAE: 0.18
# Train R2: 0.86
# Test R2: 0.83

# %% [markdown]
# Исходя из полученных метрик, можно сделать следующие выводы:
# MAE (средняя абсолютная ошибка) практически совпадает на тренировочной и тестовой выборках (0.17 и 0.18 соответственно), что свидетельствует о хорошей стабильности модели и отсутствии серьёзного переобучения. Небольшое расхождение между этими величинами несущественно и не вызывает тревоги.
# Высокая величина коэффициента детерминации на обеих выборках (0.86 на тренировочной и 0.83 на тестовой) говорит о высоком качестве модели. Значение близкое к единице показывает, что модель успешно аппроксимирует зависимость и способна хорошо объяснить значительную часть дисперсии целевой переменной.
# Общий вывод:
# Модель показала хорошие результаты как на тренировочных, так и на тестовых данных. Несмотря на небольшие различия в показателях, стабильность и высокое качество делают её надёжным инструментом для дальнейших исследований и применений.

# %%
data = {'Metric': ['Train MSE', 'Test MSE', 'Train MAE', 'Test MAE', 'Train R2', 'Test R2'],
        'NaiveModel': [0.43, 0.43, 0.48, 0.48, -0.00, -0.00],
        'LinearRegression': [0.23, 0.23, 0.35, 0.34, 0.45, 0.45],
        'RandomForestRegressor': [0.01, 0.07, 0.06, 0.16, 0.98, 0.84],
        'ElasticNetCV': [0.37, 0.38, 0.45, 0.45, 0.12, 0.11],
        'CatBoostRegressor':[0.06, 0.07, 0.17, 0.18, 0.86, 0.83]}

df_metric = pd.DataFrame(data)
df_metric.head(6)
# Out:
#       Metric  NaiveModel  LinearRegression  RandomForestRegressor  \
# 0  Train MSE        0.43              0.23                   0.01
# 1   Test MSE        0.43              0.23                   0.07
# 2  Train MAE        0.48              0.35                   0.06
# 3   Test MAE        0.48              0.34                   0.16
# 4   Train R2       -0.00              0.45                   0.98
# 5    Test R2       -0.00              0.45                   0.84
#
#    ElasticNetCV  CatBoostRegressor
# 0          0.37               0.06
# 1          0.38               0.07
# 2          0.45               0.17
# 3          0.45               0.18
# 4          0.12               0.86
# 5          0.11               0.83

# %% [markdown]
# Заключительные выводы по этому блоку:
# Давайте сравним две модели по ключевым метрикам:
#
# Первая модель (CatBoostRegressor):
# Train MAE: 0.17
# Test MAE: 0.18
# Train R²: 0.86
# Test R²: 0.83
# Вторая модель (RandomForestRegressor):
# Train MSE: 0.01
# Test MSE: 0.07
# Train MAE: 0.06
# Test MAE: 0.16
# Train R²: 0.98
# Test R²: 0.84
# Обе модели имеют высокий коэффициент детерминации, однако вторая модель снова превосходит первую на тренировочной выборке (0.98 против 0.86). Но на тестовой выборке разрыв становится минимальным (0.84 против 0.83).
# Интерпретация:
# Вторая модель показывает гораздо лучшие результаты на тренировочной выборке по всем параметрам, включая MSE, MAE и R². Она обеспечивает очень низкую ошибку на этапе обучения, что говорит о высокой способности адаптироваться к данным. Однако на тестовой выборке наблюдается некоторое снижение качества (хотя всё ещё весьма приличное). Такая ситуация может указывать на лёгкую тенденцию к переобучению, хотя общая производительность всё равно остаётся на достойном уровне.
#
# Первая модель немного уступает второй на тренировочной выборке, но проявляет большую устойчивость на тестовой выборке, демонстрируя небольшую разницу между ошибками на разных этапах.
#
# Заключение:
# модель RandomForestRegressor можно считать предпочтительной благодаря лучшей общей производительности на тренировочной выборке и приемлемым результатам на тестовой.

# %%
import pickle

# Сохранение выбранной обученной модели в файл pickle
with open("diplom_web/app/models/best_cb_model.pkl", "wb") as f:
    pickle.dump(best_cb_model, f)
